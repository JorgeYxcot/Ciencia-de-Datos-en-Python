# %% [markdown]
# ## Laboratorio: Análisis de Datos con Python
# Para este laboratorio deberá entregar el link de GitHub a un
# Notebook de Jupyter con todo el código y comentarios que
# considere necesario para dar solución a lo planteado, copie la
# pregunta en una celda de Markdown y de solución a la misma con
# las celdas de código de Python

# %% [markdown]
# ### Parte 1: Numpy:
# Para los ejercicios siguiente genere el código que considere
# para resolver el problema que se le plantea

# %% [markdown]
# 1) ¿Cuál es el tamaño en bytes de un array de 1000 elementos de tipo booleano?

# %%
import numpy as np
import pandas as pd
import sys

array = [True] * 1000
len(array)
print(sys.getsizeof(array))
# Out:
# 8056

# %% [markdown]
# 2) Cree un array cuyos elementos sean los enteros pares en [1,100] y en orden decreciente. Muestre los 10 últimos por pantalla.

# %%
even = [x for x in range(1,101) if x % 2 == 0]
#Este array, se crea con la fórmula iterable de 1 a 101, siempre y cuando el valor sea divisible entre 2.
even.reverse()
print(even)
# Out:
# [100, 98, 96, 94, 92, 90, 88, 86, 84, 82, 80, 78, 76, 74, 72, 70, 68, 66, 64, 62, 60, 58, 56, 54, 52, 50, 48, 46, 44, 42, 40, 38, 36, 34, 32, 30, 28, 26, 24, 22, 20, 18, 16, 14, 12, 10, 8, 6, 4, 2]

# %% [markdown]
# 3) Dado el array
#
# 2 4 5 6
# 0 3 7 4
# 8 8 5 2
# 1 5 6 1
#
# Seleccione con una instrucción el subarray de elementos
# 0 3 7 4
#
# Después, seleccione el subarray de elementos
# 2 5
# 8 5

# %%
x = np.array([[2, 4, 5, 6],
                  [0, 3, 7, 4],
                  [8, 8, 5, 2],
                  [1, 5, 6 ,1]])
print (x[1])
# Out:
# [0 3 7 4]

# %%
print (x[:3:2,:3:2])
# Out:
# [[2 5]
#  [8 5]]

# %% [markdown]
# Dados los arrays a = [1, 4, 2, 7] y b = [1, 3, 2, 9], obtenga la media aritmética de la diferencia (a-b).

# %%
a = np.array([1, 4, 2, 7])
b = np.array([1, 3, 2, 9])

print(np.mean(a-b))
# Out:
# -0.25

# %% [markdown]
# Tengo valores de cordenadas (x, y) en las columnas
# del array
# 1.33 4.5
# 30.0 10.7
# 70.2 0.5
#
# Agregue a este array las coordenadas (37.1, -3.6).
# Muestre en pantalla las dimensiones del nuevo
# array.

# %%
coordenadas = np.array([[1.33, 4.5],
                  [30.0, 10.7],
                  [70.2, 0.5]])

n_fila = np.array([37.1, -3.6])
new_array = np.vstack([coordenadas, n_fila])
print(new_array.shape)
print(new_array)
# Out:
# (4, 2)
# [[ 1.33  4.5 ]
#  [30.   10.7 ]
#  [70.2   0.5 ]
#  [37.1  -3.6 ]]

# %% [markdown]
# Copie el array del ejercicio anterior. Traspóngalo (Agregue ahora dos nuevos pares de coordenadas: (10.8,3.0) y (35.8, 12.0))

# %%
transpuesto = new_array.T
print(transpuesto)
# Out:
# [[ 1.33 30.   70.2  37.1 ]
#  [ 4.5  10.7   0.5  -3.6 ]]

# %%
nuevos = np.array([[10.8, 3.0], [35.8, 12.0]])
new_array = np.hstack([transpuesto,nuevos])
print(new_array)
# Out:
# [[ 1.33 30.   70.2  37.1  10.8   3.  ]
#  [ 4.5  10.7   0.5  -3.6  35.8  12.  ]]

# %% [markdown]
# ## Parte 2

# %% [markdown]
# 1) ¿Cuántos Municipios tienen más de 100000 habitantes?.

# %%
dataset = pd.read_csv("NucleosPoblacion.csv")
dataset
# Out:
#      FID  OBJECTID                           Texto  Poblacion  CodMun  \
# 0      0         1                         Agüimes    29431.0   35002
# 1      1         2                         Antigua    10458.0   35003
# 2      2         3                        Arrecife    58156.0   35004
# 3      3         4                          Arucas    36745.0   35006
# 4      4         5                          Gáldar    24473.0   35009
# ..   ...       ...                             ...        ...     ...
# 847  847       848             Infante Juan Manuel    14192.0   30030
# 848  848       849           Santa Maria de Gracia    13349.0   30030
# 849  849       850                    Vista Alegre    15208.0   30030
# 850  850       851  Poligono Sta M de Benquerencia    19177.0   45168
# 851  851       852                            Grao    16367.0   12040
#
#                                       Municipio  CodProvin  \
# 0                                       Agüimes         35
# ...

# %%
filtro = dataset[dataset["Poblacion"] > 100000]
cant = len(filtro)

print(f"Hay {cant} municipios con más de 100000 habitantes.")
# Out:
# Hay 62 municipios con más de 100000 habitantes.

# %% [markdown]
# 2. Realice una gráfica de barras sobre la población de cada provincia, ordenela de menor a mayo y responda:
#
# a. ¿Cuál es la segunda provincia más poblada?
#     R. Zamora
# b. ¿Qué posición ocupa Granada en el ranking de las ciudades más pobladas?
#     R.Posición 35

# %%
import matplotlib.pyplot as plt

df=dataset.groupby(['Provincia']).agg(
    Pob_provincia=('Poblacion', np.sum)
)
df_list = df.sort_values('Pob_provincia')
print(df_list)
# Out:
#                         Pob_provincia
# Provincia
# Soria                         39838.0
# Teruel                        51532.0
# Segovia                       55748.0
# Ávila                         58245.0
# Cuenca                        71921.0
# Melilla                       76034.0
# Ceuta                         80579.0
# Palencia                      82169.0
# Zamora                        85098.0
# Huesca                       124838.0
# Guadalajara                  139373.0
# Ourense                      161821.0
# Lugo                         162422.0
# Cáceres                      176220.0
# Salamanca                    197780.0
# Lleida                       199135.0
# La Rioja                     203911.0
# Burgos                       250766.0
# Álava                        266717.0
# Albacete                     280673.0
# León                         316662.0
# Toledo                       332751.0
# Ciudad Real                  348364.0
# ...

# %%
df=dataset.groupby(['Provincia']).agg(
    Pob_provincia=('Poblacion', np.sum)
)
df = df.sort_values('Pob_provincia').head(25)
print(df)
# Out:
#              Pob_provincia
# Provincia
# Soria              39838.0
# Teruel             51532.0
# Segovia            55748.0
# Ávila              58245.0
# Cuenca             71921.0
# Melilla            76034.0
# Ceuta              80579.0
# Palencia           82169.0
# Zamora             85098.0
# Huesca            124838.0
# Guadalajara       139373.0
# Ourense           161821.0
# Lugo              162422.0
# Cáceres           176220.0
# Salamanca         197780.0
# Lleida            199135.0
# La Rioja          203911.0
# Burgos            250766.0
# Álava             266717.0
# Albacete          280673.0
# León              316662.0
# Toledo            332751.0
# Ciudad Real       348364.0
# Badajoz           361700.0
# Huelva            361777.0

# %%
df.plot.bar()
plt.show()
#Por temas de visualización, inserté el top 25 de provincias.

# %% [markdown]
# 3) ¿Cuántos municipios de Extremadura tienen más de 5000 habitantes? *Edit: Usar málaga y 50,000

# %%
malaga=dataset[(dataset['Provincia']=='Málaga')&
               (dataset['Poblacion']>50000)]

cant_malaga = len(malaga)
print(f"Hay {cant_malaga} municipios con más de 50000 habitantes.")
# Out:
# Hay 9 municipios con más de 50000 habitantes.

# %% [markdown]
# 4) ¿Cuál es el municipio situado más al Norte? (Usar el valor de la coordenada "Y" que representa la latitud en grados). Proporcione también la provincia a la que
# pertenece y su población.

# %%
indice_municipio_norte = dataset['Y'].idxmax()
municipio_norte = dataset.loc[indice_municipio_norte]

# Imprimir los resultados
print(f"El municipio más al norte es {municipio_norte['Municipio']}, en la provincia {municipio_norte['Provincia']}, población de {municipio_norte['Poblacion']} habitantes.")
# Out:
# El municipio más al norte es Viveiro, en la provincia Lugo, población de 16211.0 habitantes.

# %% [markdown]
# 5) Obtenga la media, mediana, desviación estándar, valor
# máximo y valor mínimo de la población de los municipios
# de la provincia de Granada.

# %%
Granada = dataset[(dataset['Provincia']=='Granada')].agg(
    media = ('Poblacion',np.mean),
    suma=('Poblacion', np.sum),
    desv_est=('Poblacion', np.std),
    max=('Poblacion', np.max),
    min=('Poblacion', np.min)
)
print(Granada)
# Out:
#               Poblacion
# media      30217.850000
# suma      604357.000000
# desv_est   50355.491715
# max       239154.000000
# min        10386.000000

# %% [markdown]
# 6) Realice un histograma con la población de los Municipios para cada una de las provincias.

# %%
# Agrupar por Provincia y contar el número de municipios
prov_counts = result.groupby('Provincia').count()

for provincia in prov_counts.index:#creamos un ciclo for para cada provincia
    provincia_data = result.loc[provincia]
    municipios = provincia_data.index.get_level_values('Municipio').tolist() #al agrupar el dataframe por municipio y provincia, no podemos utilizar una variable, sino un índice
    poblacion = provincia_data['Poblacion'].tolist()
    plt.bar(municipios, poblacion)
    plt.title(f"{provincia}")
    plt.xlabel("Municipio")
    plt.ylabel("Población")
    plt.xticks(rotation=90) #rotamos el texto para que sea fácil lectura
    plt.show()

# %% [markdown]
# 7) Seleccione al azar cincuenta municipios diferentes de entre los diponibles en el archivo. Asegúrese de que no se repitan. ¿Luego calcule el promedio de la población y la desviación estándar de esto 50 municipios?.

# %%
mun=dataset.groupby(['Municipio']).agg(
    Mun_pob=('Poblacion', np.sum)
)

print(df)
# Out:
#              Pob_provincia
# Provincia
# Soria              39838.0
# Teruel             51532.0
# Segovia            55748.0
# Ávila              58245.0
# Cuenca             71921.0
# Melilla            76034.0
# Ceuta              80579.0
# Palencia           82169.0
# Zamora             85098.0
# Huesca            124838.0
# Guadalajara       139373.0
# Ourense           161821.0
# Lugo              162422.0
# Cáceres           176220.0
# Salamanca         197780.0
# Lleida            199135.0
# La Rioja          203911.0
# Burgos            250766.0
# Álava             266717.0
# Albacete          280673.0
# León              316662.0
# Toledo            332751.0
# Ciudad Real       348364.0
# Badajoz           361700.0
# Huelva            361777.0

# %%
sample = mun.sample(n=50)
mun = mun.drop(sample.index)

print (sample)
# Out:
#                           Mun_pob
# Municipio
# Castellar del Vallès      23129.0
# Torroella de Montgrí      11522.0
# Chiclana de la Frontera   78591.0
# Zarautz                   22658.0
# Fraga                     14539.0
# Torrijos                  13374.0
# Algeciras                116417.0
# Cerdanyola del Vallès     58407.0
# Esplugues de Llobregat    46649.0
# Puçol                     19295.0
# Arrasate/Mondragón        22011.0
# Vícar                     23410.0
# Pinos Puente              13421.0
# Fene                      14092.0
# Astorga                   12015.0
# Badia del Vallès          13703.0
# Icod de los Vinos         24231.0
# Jumilla                   26015.0
# Haro                      11960.0
# Badajoz                  150376.0
# Alcalá del Río            11004.0
# Sant Pere de Ribes        40023.0
# Brenes                    12580.0
# Onda                      25778.0
# Illescas                  22482.0
# Guardamar del Segura      16423.0
# ...

# %%
promedio = sample.mean()
desv = sample.std()

print(f'Promedio:{promedio}')
print(f'Desviación estándar:{desv}')
# Out:
# Promedio:Mun_pob    31410.92
# dtype: float64
# Desviación estándar:Mun_pob    29521.187065
# dtype: float64

# %% [markdown]
# 8) Dígame los nombres de los Municipios más cercano y más lejano a Madrid. Para ello debe calcular la distancia en todos ellos y Madrid. No considere a Madrid en el análisis ya que la distancia sería cero.

# %%
dist = dataset
dist['M'] = abs(np.sqrt((dist['X']**2) + dist['Y']**2) - 40.5890)
dist = dist.drop(dist[dist['Municipio'] == 'Madrid'].index)

lejano = dist.loc[dist['M'].idxmax(), 'Municipio']
cercano = dist.loc[dist['M'].idxmin(), 'Municipio']

print(f"El municipio más lejano es: {lejano}.")
print(f"El municipio más cercano es: {cercano}.")
# Out:
# El municipio más lejano es: Tuineje.
# El municipio más cercano es: Boadilla del Monte.
